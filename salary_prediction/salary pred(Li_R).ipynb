# %% [markdown]
# IMPORTING LIBRARIES:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# LOADING THE DATA:

# %%
ds=pd.read_csv(r"Salary Data.csv")

# %%
ds
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
df=pd.DataFrame(ds)
df["Gender"]=df["Gender"].map({'Male':0,'Female':1})

# %% [markdown]
# DATA PREPROCESSING:

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Education Level"]=le.fit_transform(df["Education Level"])
print(df)
# Out:
#       Age  Gender  Education Level                      Job Title  \
# 0    32.0     0.0                0              Software Engineer
# 1    28.0     1.0                1                   Data Analyst
# 2    45.0     0.0                2                 Senior Manager
# 3    36.0     1.0                0                Sales Associate
# 4    52.0     0.0                1                       Director
# ..    ...     ...              ...                            ...
# 370  35.0     1.0                0       Senior Marketing Analyst
# 371  43.0     0.0                1         Director of Operations
# 372  29.0     1.0                0         Junior Project Manager
# 373  34.0     0.0                0  Senior Operations Coordinator
# 374  44.0     1.0                2        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
df=df.drop(172)
df=df.drop(260)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 369 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  369 non-null    float64
#  1   Gender               369 non-null    float64
#  2   Education Level      369 non-null    int64
#  3   Job Title            369 non-null    object
#  4   Years of Experience  369 non-null    float64
#  5   Salary               369 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 20.2+ KB

# %%
df.describe()
# Out:
#               Age      Gender  Education Level  Years of Experience  \
# count  369.000000  369.000000       369.000000           369.000000
# mean    37.425474    0.479675         0.533875            10.016260
# std      7.062262    0.500265         0.721989             6.557004
# min     23.000000    0.000000         0.000000             0.000000
# 25%     31.000000    0.000000         0.000000             4.000000
# 50%     36.000000    0.000000         0.000000             9.000000
# 75%     44.000000    1.000000         1.000000            15.000000
# max     53.000000    1.000000         2.000000            25.000000
#
#               Salary
# count     369.000000
# mean   100407.452575
# std     48261.033375
# min       350.000000
# 25%     55000.000000
# 50%     95000.000000
# 75%    140000.000000
# max    250000.000000

# %% [markdown]
# SPLITTING THE DATA:

# %%
x=df.iloc[:,[0,1,2,5]].values
y=df.iloc[:,4].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %% [markdown]
# TRAINING THE DATA:

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_pred,y_test)
print("The mean squared error is:",mse)
# Out:
# The mean squared error is: 1.2020461067399588

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_pred,y_test)
print("The mean absolute error is:",mae)
# Out:
# The mean absolute error is: 0.8761932544828333

# %%
rmse=np.sqrt(mse)
print("The root mean squared error:",rmse)
# Out:
# The root mean squared error: 1.0963786329274932
